# %% [markdown]
# <a href="https://colab.research.google.com/github/qorwlghks/26-BDA/blob/main/05w_matplotlib_subplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')
plt.rc('axes', unicode_minus = False)

# %%
# !pip install koreanize-matplotlib
import koreanize_matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 30.4 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# Install Korean font 'NanumBarunGothic'
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# Note: After installing fonts, restarting the runtime is often necessary.
# fm.fontManager.rebuild() # This method caused an AttributeError, so it's removed.

# Set font to 'NanumBarunGothic'
plt.rc('font', family='NanumBarunGothic')
plt.rc('axes', unicode_minus=False)

print("Font 'NanumBarunGothic' installed.")
print("Please restart the Colab runtime (Runtime > Restart runtime...) to apply the font changes.")
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Font 'NanumBarunGothic' installed.
# Please restart the Colab runtime (Runtime > Restart runtime...) to apply the font changes.

# %%
import matplotlib.pyplot as plt

plt.suptitle('전체 제목', fontsize=14, y=1.02)

plt.subplot(2, 3, 1)
plt.plot([1, 4, 9, 16])
plt.title('제곱수')

plt.subplot(2, 3, 6)
plt.plot([1, 2, 3, 4])
plt.title('선형')

plt.subplot(2, 3, 2)
plt.plot([6, 5, 2, 1])
plt.title('감소')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(2, 3, figsize=(7, 4))
fig.set_size_inches(6, 3)
ax[0, 1].plot([1, 4, 9, 16])
ax[1, 0].plot([1, 2, 3, 4])
ax[1, 2].plot([6, 5, 2, 1])

fig.suptitle('전체 제목', fontsize=14, fontweight='bold')

ax[0, 0].set_title('(0,0) 빈 플롯')
ax[0, 1].set_title('(0,1) 제곱수')
ax[0, 2].set_title('(0,2) 빈 플롯')
ax[1, 0].set_title('(1,0) 선형')
ax[1, 1].set_title('(1,1) 빈 플롯')
ax[1, 2].set_title('(1,2) 감소')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(6, 4))
ax1 = fig.add_subplot(231)
ax1.plot([1, 4, 9, 16])
ax1.set_title('제곱수')
ax2 = fig.add_subplot(233)
ax2.plot([1, 2, 3, 4])
ax2.set_title('선형')
ax3 = fig.add_subplot(235)
ax3.plot([6, 5, 2, 1])
ax3.set_title('감소')
fig.suptitle('전체 제목', fontsize=14)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np

age = pd.Series([9,17,32,45,65,98], index=list('abcdef'), name='age')
age
# Out:
# a     9
# b    17
# c    32
# d    45
# e    65
# f    98
# Name: age, dtype: int64

# %%
int(age['b'])
# Out:
# 17

# %%
age[[1,3,5]]
# Out:
# /tmp/ipykernel_14365/2675513065.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   age[[1,3,5]]
# b    17
# d    45
# f    98
# Name: age, dtype: int64

# %%
age[['b','f','c']]
# Out:
# b    17
# f    98
# c    32
# Name: age, dtype: int64

# %%
age['c']
# Out:
# np.int64(32)

# %%
age[['c']]
# Out:
# c    32
# Name: age, dtype: int64
